# %%
require 'daru'
# Out:
# false

# %% [markdown]
# # Daru
# Daru provides some data structures which are widely used in data science. They provide functionality for easily manipulating, subsetting, combining, and aggregating data. The primary structures provided by daru are vectors and data frames.

# %% [markdown]
# ## Vectors
# Conceptually, vectors are very similar to a ruby `Array`. However, daru's vectors are typed - meaning that each element of a vector must be of the same logical type (Integer, String, Boolean, etc.).
#
# In addition to many of the methods you would expect on an Array, vectors include additional functionality for statistical methods, aggregation, plotting and other things.
#
# ### Making a new vector

# %%
numbers = Daru::Vector.new( (1..100).map { rand(100) })
# Out:
# #<Daru::Vector(100)>
#    0  57
#    1  59
#    2  98
#    3  82
#    4  51
#    5  69
#    6  68
#    7  53
#    8  97
#    9  37
#   10   2
#   11  15
#   12  28
#   13  83
#   14  11
#  ... ...

# %% [markdown]
# #### Aggregation
# Sum, count , average, standard deviation

# %%
numbers.std
# Out:
# 27.60247939383106

# %% [markdown]
# # Daru - Data frames for Ruby
# Data frames are tabular data structures for storing observational data. Conceptually, a data frame is a collection of vectors where each vector is the same length but does not have to be of the same type.

# %%
data = [
    { age: 32, gender: 'f' },
    { age: 21, gender: 'm' },
    { age: 25, gender: 'f' },
    { age: 46, gender: 'f' },
    { age: 54, gender: 'm' },
    { age: 53, gender: 'm' },
]
# Out:
# [{:age=>32, :gender=>"f"}, {:age=>21, :gender=>"m"}, {:age=>25, :gender=>"f"}, {:age=>46, :gender=>"f"}, {:age=>54, :gender=>"m"}, {:age=>53, :gender=>"m"}]

# %%
dataframe = Daru::DataFrame.new(data)
# Out:
# #<Daru::DataFrame(6x2)>
#            age gender
#       0     32      f
#       1     21      m
#       2     25      f
#       3     46      f
#       4     54      m
#       5     53      m

# %% [markdown]
# ### NHANES
# NHANES is a data set collected and released by the CDC. It contains data about the health and nutrition of people around the nation.
#
# Let's explore NHANES a bit.

# %%
nhanes_url = 'https://raw.githubusercontent.com/ProjectMOSAIC/NHANES/master/data-raw/NHANES.csv'
nhanes = Daru::DataFrame.from_csv(nhanes_url); nil

p "Loaded #{nhanes.size} rows"
# Out:
# "Loaded 10000 rows"
# "Loaded 10000 rows"

# %%
nhanes
# Out:
# #<Daru::DataFrame(6832x29)>
#                   Year LocationAb LocationDe DataSource PriorityAr PriorityAr PriorityAr PriorityAr   Category      Topic  Indicator Data_Value Data_Value Data_Value Data_Value Data_Value Data_Value Confidence Confidence Break_Out_  Break_Out CategoryId    TopicId IndicatorI Data_Value BreakOutCa BreakOutId LocationID GeoLocatio
#           0  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence Age-Standa Percent (%        7.0        7.0        nil        nil        6.0        8.1    Overall    Overall         C1         T1      NH001    AgeStdz      BOC01      OVR01         59        nil
#           1  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        6.4        6.4        nil        nil        5.6        7.4    Overall    Overall         C1         T1      NH001      Crude      BOC01      OVR01         59        nil
#           2  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        8.0        8.0        nil        nil        6.6        9.7     Gender       Male         C1         T1      NH001      Crude      BOC02      GEN01         59        nil
#           3  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence Age-Standa Percent (%        9.1        9.1        nil        nil        7.5       11.0     Gender       Male         C1         T1      NH001    AgeStdz      BOC02      GEN01         59        nil
#           4  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        5.0        5.0        nil        nil        4.1        6.1     Gender     Female         C1         T1      NH001      Crude      BOC02      GEN02         59        nil
#           5  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence Age-Standa Percent (%        5.2        5.2        nil        nil        4.2        6.3     Gender     Female         C1         T1      NH001    AgeStdz      BOC02      GEN02         59        nil
#           6  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        nil       -2.0          ~ Statistica        nil        nil        Age      20-24         C1         T1      NH001      Crude      BOC03      AGE02         59        nil
#           7  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        1.1        1.1        nil        nil        0.6        1.9        Age      25-44         C1         T1      NH001      Crude      BOC03      AGE04         59        nil
#           8  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        8.6        8.6        nil        nil        7.1       10.3        Age      45-64         C1         T1      NH001      Crude      BOC03      AGE05         59        nil
#           9  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%       21.4       21.4        nil        nil       18.5       24.7        Age        65+         C1         T1      NH001      Crude      BOC03      AGE06         59        nil
#          10  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        9.1        9.1        nil        nil        7.7       10.8        Age        35+         C1         T1      NH001      Crude      BOC03      AGE07         59        nil
#          11  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%       25.2       25.2        nil        nil       21.0       30.0        Age        75+         C1         T1      NH001      Crude      BOC03      AGE08         59        nil
#          12  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        7.3        7.3        nil        nil        6.2        8.5       Race Non-Hispan         C1         T1      NH001      Crude      BOC04      RAC01         59        nil
#          13  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence      Crude Percent (%        5.4        5.4        nil        nil        4.3        6.8       Race Non-Hispan         C1         T1      NH001      Crude      BOC04      RAC02         59        nil
#          14  1999-2000         US United Sta     NHANES       None       None       None       None Cardiovasc Major Card Prevalence Age-Standa Percent (%        7.3        7.3        nil        nil        5.6        9.4       Race Non-Hispan         C1         T1      NH001    AgeStdz      BOC04      RAC02         59        nil
#         ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...
